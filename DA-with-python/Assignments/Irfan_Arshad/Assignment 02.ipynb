# %% [markdown]
# # Part -2 Python Basics (Conditional Statements)

# %% [markdown]
# 1) A company decided to give bonus of 5% to employee if his/her year of service is more than 5 years.
# Ask user for their salary and year of service and print the net bonus amount.

# %%
#Type your code here
salary = float(input("Enter Salary:"))
year = float(input("Enter Year:"))
if year > 5:
    bonus = salary*0.05
    print("Your net bouns:", bonus)
else:
    print("Company not provide bonus:")
# Out:
# Company not provide bonus:

# %% [markdown]
# 2) Write a program to check whether a person is eligible for voting or not. (accept age from user) if age is greater than 17 eligible otherwise not eligible

# %%
#Type your code here
user_age = int(input("Enter your age:"))
if user_age > 17:
    print(f"You are eligible for vote beacuse your age is :{user_age}")
else:
    print(f"You are not eligible for vote your age is {user_age}, you eligible after {17-user_age} year")
# Out:
# You are not eligible for vote your age is 12 you eligible after 5 year

# %% [markdown]
# 3) Write a program to check whether a number entered by user is even or odd.

# %%
#Type your code here
num = int(input("Enter a Number:"))
if num % 2  ==0:
    print("Even Num")
else:
    print("Odd num")
# Out:
# Odd num

# %% [markdown]
# 4) Write a program to check whether a number is divisible by 7 or not.
# Show Answer

# %%
#Type your code here
num = int(input("Enter a Number:"))
if num % 7  ==0:
    print("Num Divisible by 7")
else:
    print("Num not Divisible by 7")
# Out:
# Num Divisible by 7

# %% [markdown]
# 5) Write a program to display
# "Hello" if a number entered by user is a multiple of five , otherwise print "Bye".

# %%
#Type your code here
num = int(input("Enter a Number:"))
if num % 5  ==0:
    print("Hello")
else:
    print("By ")
# Out:
# Hello

# %% [markdown]
# 7) Write a program to display the last digit of a number.

# %%
#Type your code here
num = [1,2,3,4,5,11]
print(num[-1])
# Out:
# 11

# %% [markdown]
# 9) Take values of length and breadth of a rectangle from user and print if it is square or rectangle.

# %%
#Type your code here 
length = int(input("Enter length:"))
breadth = int(input("Enter breath:"))
if length == breadth:
    print("Square")
else:
    print("Rectangle")
# Out:
# Square

# %% [markdown]
# 10) Take two int values from user and print greatest among them.

# %%
# Type your code here
num1 = int(input("Enter a Number1:"))
num2 = int(input("Enter a Number2:"))
if num1 > num2:
    print("Greatest")
# Out:
# Greatest

# %% [markdown]
# 11) A shop will give discount of 10% if the cost of purchased quantity is more than 1000.
# Ask user for quantity
# Suppose, one unit will cost 100.
# Judge and print total cost for user.

# %%
#Type your code here
quantity = float(input("Enter quantity"))
cost = quantity * 100
if cost > 1000:
    dis = cost * 0.10 # 10% discount
    total_cost = cost - dis
    print("Total cost:", total_cost)
# Out:
# Total cost: 1800.0

# %% [markdown]
# 12) A school has following rules for grading system:
#
# a. Below 25 - F
#
# b. 25 to 45 - E
#
# c. 45 to 50 - D
#
# d. 50 to 60 - C
#
# e. 60 to 80 - B
#
# f. Above 80 - A
#
# Ask user to enter marks and print the corresponding grade.

# %%
#Type your code here
marks = int(input("Enter a student marks:"))
if marks > 80:
    print("A")
elif marks >= 60: 
    print("B")
elif marks >= 50: 
    print("C")
elif marks >= 45: 
    print("D")
elif marks >= 25: 
    print("E")
else:
    print("F")
# Out:
# C

# %% [markdown]
# 14)A student will not be allowed to sit in exam if his/her attendence is less than 75%.
#
# Take following input from user
#
# - Number of classes held
#
# - Number of classes attended.
#
# And print
#
# - percentage of class attended
#
# - Is student is allowed to sit in exam or not.

# %%
#Type your code here
classes_held = int(input("Enter a classes"))
classes_attended = int(input("Enter a attended classes"))
per = (classes_attended/classes_held) * 100
if per > 0.75 : 
    print("Allowed in exm beacuse your per", per)
else:
    print("Not allowed in exm because your % not greater than 75", per)
# Out:
# Allowed in exm beacuse your per 76.92307692307693

# %% [markdown]
# 15) Modify the above question to allow student to sit if he/she has medical cause. Ask user if he/she has medical cause or not ( 'Y' or 'N' ) and print accordingly.

# %%
#Type your code here
classes_held = int(input("Enter a classes"))
classes_attended = int(input("Enter a attended classes"))
medical = input("Enter medical case Y/N")
per = (classes_attended/classes_held) * 100
if (per > 0.75 or medical == "Y"):

    print("Allowed in exm beacuse your percentage", per)
else:
    print("Not allowed in exm because your % not greater than 75", per)
# Out:
# Allowed in exm beacuse your per 68.0

# %% [markdown]
# 16) Write a program to check if a year is leap year or not.
#
# If a year is divisible by 4 then it is leap year but if the year is century year like 2000, 1900, 2100 then it must be divisible by 400.

# %%
#Type your code here
year = int(input('Enter a year'))
if (year % 400== 0 or year % 4 ==0):
    print("Leap year")
else:
    print("Not leap year")
# Out:
# Not leap year

# %% [markdown]
# 17) Ask user to enter age, gender ( M or F ), marital status ( Y or N ) and then using following rules print their place of service.
#
# if employee is female, then she will work only in urban areas.
#
# if employee is a male and age is in between 20 to 40 then he may work in anywhere
#
# if employee is male and age is in between 40 t0 60 then he will work in urban areas only.
#
# And any other input of age should print "ERROR"

# %%
#Type your code here
age = int(input("Enter an age:"))
gender = input("Enter a gender:")

if (gender == 'female' or gender == "Female"):
    print("She will work only in urban areas")

elif (gender == 'male' or gender == "Male") and age >= 20 and age <=40:
    print("They work in anywhere")   

elif (gender == 'male' or gender == "Male") and age >= 40 and age <=60:
    print("They work in urban areas only")
else:
    print("ERROR")
# Out:
# She will work only in urban areas

# %% [markdown]
# 6) Write a program to calculate the electricity bill (accept number of unit from user) according to the following criteria :
#      Unit                                                     Price
# uptp 100 units                                             no charge
# Next 200 units                                              Rs 5 per unit
# After 200 units                                             Rs 10 per unit
# (For example if input unit is 350 than total bill amount is Rs.3500
# (For example if input unit is 97 than total bill amount is Rs.0
# (For example if input unit is 150 than total bill amount is Rs.750

# %%
#Type your code here
units = int(input("enter a units:"))

if units <= 100:
    print('Total amount of bill is 0')

elif (units > 100 and units <=200):
    amount = units * 5
    print("Total bill amount is:", amount)

else:
    bill = units * 10
    print("Total bill amount is:", bill)
# Out:
# Total amount of bill is 0

# %% [markdown]
# 13) Take input of age of 3 people by user and determine oldest and youngest among them.

# %%
age1 = int(input("Enter a age1"))
age2 = int(input("Enter a age2"))
age3 = int(input("Enter a age3"))
print("Youngest",min(age1,age2,age3))
print("Oldest" ,max(age1,age2,age3))
# Out:
# Youngest 33
# Oldest 55
